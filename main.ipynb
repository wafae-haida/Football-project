# %% [markdown]
# Processing Agent

# %% [markdown]
# Actions analysis agent

# %%
from multi_agent_system.crews.action_analysis_crew import run_action_analysis_crew

result = run_action_analysis_crew(
    "dataset/processing/data/test_data.json"
)

print(result)
# Out:
# ╭──────────────────────────────────────────── ✨ Update Available ✨ ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  A new version of CrewAI is available!                                                                          │
# │                                                                                                                 │
# │  Current version: 1.14.4                                                                                        │
# │  Latest version:  1.14.7                                                                                        │
# │                                                                                                                 │
# │  To update, run: uv sync --upgrade-package crewai                                                               │
# ...

# %% [markdown]
# Analyse spacial agent

# %%
from multi_agent_system.crews.spatial_analysis_crew import run_spatial_analysis_crew

result = run_spatial_analysis_crew(
    data_file="dataset/processing/data/test_data.json",
    action_batches_dir="dataset/action_analysis/data/test_batches"
)

print(result)
# Out:
# ╭──────────────────────────────────────────── ✨ Update Available ✨ ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  A new version of CrewAI is available!                                                                          │
# │                                                                                                                 │
# │  Current version: 1.14.4                                                                                        │
# │  Latest version:  1.14.7                                                                                        │
# │                                                                                                                 │
# │  To update, run: uv sync --upgrade-package crewai                                                               │
# ...

# %% [markdown]
# Analyse graph agent

# %%
from multi_agent_system.crews.graph_analysis_crew import run_graph_analysis_crew

result = run_graph_analysis_crew(
    data_file="dataset/processing/data/test_data.json",
    action_batches_dir="dataset/action_analysis/data/test_batches",
    spatial_batches_dir="dataset/spatial_analysis/data/test_batches"
)

print(result)
# Out:
# ╭──────────────────────────────────────────── ✨ Update Available ✨ ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  A new version of CrewAI is available!                                                                          │
# │                                                                                                                 │
# │  Current version: 1.14.4                                                                                        │
# │  Latest version:  1.14.7                                                                                        │
# │                                                                                                                 │
# │  To update, run: uv sync --upgrade-package crewai                                                               │
# ...

# %% [markdown]
# Entrainement du modèle

# %%
from multi_agent_system.crews.model_training_crew import run_model_training_crew

result = run_model_training_crew()

print(result)
# Out:
# ╭──────────────────────────────────────────── ✨ Update Available ✨ ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  A new version of CrewAI is available!                                                                          │
# │                                                                                                                 │
# │  Current version: 1.14.4                                                                                        │
# │  Latest version:  1.14.7                                                                                        │
# │                                                                                                                 │
# │  To update, run: uv sync --upgrade-package crewai                                                               │
# ...

# %% [markdown]
# StreamLite plateform

# %%
# !streamlit run streamlit_app/main.py
