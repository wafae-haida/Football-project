# %%
from multi_agent_system.crews.data_processing_crew import run_data_processing_crew

result = run_data_processing_crew(
    "dataset/split/test"
)

print(result)
# Out:
# ╭──────────────────────────────────────────── ✨ Update Available ✨ ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  A new version of CrewAI is available!                                                                          │
# │                                                                                                                 │
# │  Current version: 1.14.4                                                                                        │
# │  Latest version:  1.14.7                                                                                        │
# │                                                                                                                 │
# │  To update, run: uv sync --upgrade-package crewai                                                               │
# ...
